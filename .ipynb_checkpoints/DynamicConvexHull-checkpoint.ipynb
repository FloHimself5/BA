# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def returnPoint(self):
        return (self.x, self.y)

# %%
class InnerNode:
    def __init__(self, idd = None, f = None, lson = None, rson = None, maxY = None, Q = None, B = None):
        self.idd = idd #Debugging
        self.f = f #pointer to father
        self.lson = lson #pointer to left son
        self.rson = rson #pointer to right son
        self.maxY = maxY #largest y-value in subtree of lson
        self.Q = Q #segment of Q_a that did not contribute to Q_f
        self.B = B #number of points of Q_a that contribute to Q_f
    
    def printData(self):
        printID = self.idd
        if self.f:
            printF = self.f
        else:
            printF = "NONE"
        
        if(type(self.lson) is list):
            printLson = "["
            for i in range(len(self.lson)-1):
                printLson += "{},".format(self.lson[i].y)
            printLson += "{}".format(self.lson[len(self.lson)-1].y)
            printLson += "]"
        else:
            printLson = self.lson.y
        if(type(self.rson) is list):
            printRson = "["
            for i in range(len(self.rson)-1):
                printRson += "{},".format(self.rson[i].y)
            printRson += "{}".format(self.rson[len(self.rson)-1].y)
            printRson += "]"
        else:
            printRson = self.rson.y
        printMaxY = self.maxY
        if self.Q:
            printQ = "["
            for i in range(len(self.Q)-1):
                printQ += "{},".format(self.Q[i].y)
            printQ += "{}".format(self.Q[len(self.Q)-1].y)
            printQ += "]"
        else:
            printQ = "NONE"
        if self.B:
            printB = self.B
        else:
            printB = "NONE"
            
        print("id: {}, f: {}, lson: {}, rson: {}, maxY: {}, Q: {}, B: {}".format(printID, printF, printLson, printRson, printMaxY, printQ, printB))

# %%
import math
def create_points_circle(r, n):
    pi = math.pi
    points = []
    for i in range(n):
        x = math.cos(2*pi*(np.random.rand()*max)/n*i)*r *(np.random.rand())
        y = math.sin(2*pi*(np.random.rand()*max)/n*i)*r *(np.random.rand())
        p = Point(x+r, y+r)
        points.append(p)
    return points

# %%
import math
def create_points_arc(r, n, offsetY=0):
    pi = math.pi
    n = n * 2 
    points = []
    for i in range(n):
        x = math.cos(2*pi/n*i)*r
        y = math.sin(2*pi/n*i)*r
        if(x <= 0):
            x += r
            y += r + offsetY
            x = math.ceil(x)
            y = math.ceil(y)
            p = Point(x, y)
            points.append(p)
    return points

# %%
def plotPoints(points, Y0, showAngles=False, hull=None):
    n = len(points)
    if(showAngles == True):
        point1 = [Y0.x, Y0.y]
        for i in range(n):
            point2 = [points[i].x,points[i].y]
            x_values = [point1[0], point2[0]]
            y_values = [point1[1], point2[1]]
            plt.plot(x_values, y_values, 'b-', linewidth=0.1)
            plt.plot(point2[0], point2[1], 'b.')
    
    if hull:
        x0 = hull[0].x
        y0 = hull[0].y
        
        for p in hull[1:]:
            x1 = p.x
            y1 = p.y
            plt.plot([x0, x1], [y0, y1])
            x0, y0 = x1, y1
        
    
    for i in range(n):
        plt.plot(points[i].x, points[i].y, "b.")
    plt.plot(Y0.x, Y0.y, "go")
    plt.show()

# %%
def printList(points):
    for i in range(len(points)):
        print(points[i].x, points[i].y)

# %%
def isBetween(a, b, c):
    epsilon = 0.1
    crossproduct = (c.y - a.y) * (b.x - a.x) - (c.x - a.x) * (b.y - a.y)

    # compare versus epsilon for floating point values, or != 0 if using integers
    if abs(crossproduct) > epsilon:
        return False

    dotproduct = (c.x - a.x) * (b.x - a.x) + (c.y - a.y)*(b.y - a.y)
    if dotproduct < 0:
        return False

    squaredlengthba = (b.x - a.x)*(b.x - a.x) + (b.y - a.y)*(b.y - a.y)
    if dotproduct > squaredlengthba:
        return False

    return True

# %%
def isIntersecting(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    
    if div == 0:
        return np.inf, np.inf
        #return False
       #raise Exception('lines do not intersect')

    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    #return True
    
    p1 = Point(line2[0][0], line2[0][1])
    p2 = Point(line2[1][0], line2[1][1])
    
    if(isBetween(p1, p2, Point(x,y))):
    
    #if(isBetween(line2[0][0], line2[1][0], x) and isBetween(line2[0][1], line2[1][1], y)):
        return x, y
    return np.inf, np.inf

#print line_intersection((A, B), (C, D))

# %%
### ALL DRAWING STUFF
#fig, (ax0, ax1) = plt.subplots(1, 2)

def drawQStructure(Q, ax):
    x0 = Q[0].x
    #x0 = max
    y0 = Q[0].y
    for p in Q:# range(len(Q)):
        
        x1 = p.x
        y1 = p.y
        #plt.plot([x0, x1], [y0, y1])
        #ax.plot([x0, x1], [y0, y1])

    #x0, y0 = x1, y1
    #ax.plot([x0, max], [y0, y1])

    
    for i in range(len(Q)):
        ax.plot(Q[i].x, Q[i].y, "b.")
        

def drawIntersection(p,q,a,b, ax):
    ax.plot([p[0], q[0]], [p[1], q[1]], 'k-', linewidth=0.5, alpha=0.7)
    ax.plot([a[0], b[0]], [a[1], b[1]], 'g-', linewidth=0.5)

        
def drawPQ(p,q,ax):
    ax.plot(p[0], p[1], "ro")
    ax.plot(q[0], q[1], "ro")


def drawPointColor(x, y, col, ax):
    ax.plot(x, y, col)   
        
def correctPlot(fig):
    n = len(fig.axes)
    for i in range(n):
        #fig.axes[i].change_geometry(n+1, 1, i+1)
        fig.axes[i].change_geometry(1, n+1, i+1)
    return fig

# %%
def scale(p1,p2,factor):
    t0=0.5*(1.0-factor)
    t1=0.5*(1.0+factor)
    x1 = p1[0] +(p2[0] - p1[0]) * t0
    y1 = p1[1] +(p2[1] - p1[1]) * t0
    x2 = p1[0] +(p2[0] - p1[0]) * t1
    y2 = p1[1] +(p2[1] - p1[1]) * t1
    return [x1,y1],[x2,y2]
    #return Point(x1,y2),Point(x2,y2)
    #self.firstPoint = Point(x1, y1)
    #self.secondPoint = Point(x2, y2)

# %%
def checkDuplicate(p1,p2):
    if(p1[0] - p2[0] == 0 and p1[1] - p2[1] == 0):
        return True
    return False

# %%
def findBridge(Q_A, Q_C,fig, iteration, draw=True):
    print("============= ITERATION: {} =============".format(iteration))
    #t is tangent to lc-hull
    if(iteration > 5):
        return
    #figLength = len(axList)
    if(draw):
        figLength = len(fig.axes)
        axCurr = fig.add_subplot(figLength+1, 1, figLength+1)
    
        correctPlot(fig)
        
        drawQStructure(Q_A, axCurr)
        drawQStructure(Q_C, axCurr)
    #currAx = axList[figLength-1]
    
    #ax.plot([4,5,6])
    
   # for i in range(len(Q_A)):
    #    plt.plot(Q_A[i].x, Q_A[i].y, "b.")
            
    #for i in range(len(Q_C)):
     #   plt.plot(Q_C[i].x, Q_C[i].y, "b.")
    
    
    if True:
        if(len(Q_A) < 2):
            pID = 0
        else:
            pID = math.floor(len(Q_A)/2)

        if(len(Q_C) < 2):
            qID = 0
        else:
            qID = math.floor(len(Q_C)/2)
    else:
        if(len(Q_A) > 1):
            pID = 1
        else:
            pID = 0
        if(len(Q_C) > 1):
            qID = 1
        else:
            qID = 0
    
    print("Q_A LENGTHT: ", len(Q_A))
    print("Q_C LENGTHT: ", len(Q_C))
    
    
    p = [Q_A[pID].x, Q_A[pID].y]
    q = [Q_C[qID].x, Q_C[qID].y]
    
    print("::: ALL INFOS :::")
    print("Q_A")
    printList(Q_A)
    print("Q_C")
    printList(Q_C)
    print("p: ",p, "q: ",q)
    
    
    pScaled, qScaled = scale(p,q,3)
    t = [pScaled, qScaled]
         
    #a,b for Q_A
    #c,d for Q_C
    
    InterListA = []
    
    for i in range(1, len(Q_A)):
        a = [Q_A[i-1].x, Q_A[i-1].y]
        b = [Q_A[i].x, Q_A[i].y]
        
        #print("checking section {},{} - {},{}".format(a[0],a[1],b[0],b[1]))
        if(draw):
            drawIntersection(t[0], t[1], a, b, axCurr)
        intersect = isIntersecting(t,(a,b))
        if(intersect[1] < np.inf):
            InterListA.append(intersect)
            #print("Is Intersecting on A: ",intersect)
            
    #check infinite edges
    a = [Q_A[0].x, Q_A[0].y]
    b = [Q_A[0].x + max, Q_A[0].y]
    
    if(draw):
        drawIntersection(t[0], t[1], a, b, axCurr)
    intersect = isIntersecting(t,(a,b))
    if(intersect[1] < np.inf):
        InterListA.append(intersect)
    
    a = [Q_A[len(Q_A)-1].x, Q_A[len(Q_A)-1].y]
    b = [Q_A[len(Q_A)-1].x + max, Q_A[len(Q_A)-1].y]
    
    if(draw):
        drawIntersection(t[0], t[1], a, b, axCurr)
    intersect = isIntersecting(t,(a,b))
    if(intersect[1] < np.inf):
        InterListA.append(intersect)
    
    
    InterListC = []
    
    for i in range(1, len(Q_C)):
        c = [Q_C[i-1].x, Q_C[i-1].y]
        d = [Q_C[i].x, Q_C[i].y]
        
        #print("checking section {},{} - {},{}".format(c[0],c[1],d[0],d[1]))
        if(draw):
            drawIntersection(t[0], t[1], c, d, axCurr)
        intersect = isIntersecting(t,(c,d))
        if(intersect[1] < np.inf):
            InterListC.append(intersect)
            #print("Is Intersecting on C: ",intersect)
    
     #check infinite edges
    c = [Q_C[0].x, Q_C[0].y]
    d = [Q_C[0].x + max, Q_C[0].y]
    
    if(draw):
        drawIntersection(t[0], t[1], c, d, axCurr)
    intersect = isIntersecting(t,(c,d))
    if(intersect[1] < np.inf):
        InterListC.append(intersect)
    
    c = [Q_C[len(Q_C)-1].x, Q_C[len(Q_C)-1].y]
    d = [Q_C[len(Q_C)-1].x + max, Q_C[len(Q_C)-1].y]
    
    if(draw):
        drawIntersection(t[0], t[1], c, d, axCurr)
    intersect = isIntersecting(t,(c,d))
    if(intersect[1] < np.inf):
        InterListC.append(intersect)
    
    if(draw):
        drawPQ(p,q,axCurr)
    
    

    #Check lists for duplicats
    if(len(InterListA) > 1):
        for i in range(len(InterListA)-1, 0, -1):
            #if(InterListA[i][0] - InterListA[i-1][0] == 0 and InterListA[i][1] - InterListA[i-1][1] == 0):
            if(checkDuplicate(InterListA[i], InterListA[i-1])):
                InterListA.pop(i)
    
    if(len(InterListC) > 1):
        for i in range(len(InterListC)-1, 0, -1):
            #if(InterListC[i][0] - InterListC[i-1][0] == 0 and InterListC[i][1] - InterListC[i-1][1] == 0):
            if(checkDuplicate(InterListC[i], InterListC[i-1])):
                InterListC.pop(i)

    print("INTER LIST A: {}: {}".format(len(InterListA), InterListA))
    print("INTER LIST C: {}: {}".format(len(InterListC), InterListC))
    
    #for i in range(len(InterListA)):
   #     plt.plot(InterListA[i][0], InterListA[i][1], "ro")
    
   # for i in range(len(InterListC)):
    #    plt.plot(InterListC[i][0], InterListC[i][1], "ro")
    
    if(len(InterListA) == 1):
        print("p on A found!")
        pFinal = Point(InterListA[0][0], InterListA[0][1])
        
    if(len(InterListC) == 1):
        print("q on C found!")
        qFinal = Point(InterListC[0][0], InterListC[0][1])
    
############################    
#### CASE DETERMINATION ####
############################

    
    
    InterA = [np.inf, np.inf]
    InterC = [np.inf, np.inf]
    
    if(len(InterListA) > 1):
        for i in range(len(InterListA)):
            if(not checkDuplicate(InterListA[i], p)):
                InterA = InterListA[i]

    if(len(InterListC) > 1):
        for i in range(len(InterListC)):
            if(not checkDuplicate(InterListC[i], q)):
                InterC = InterListC[i]
                
    
                
    if(InterA[1] < np.inf):
        if(draw):
            drawPointColor(InterA[0], InterA[1], "mo", axCurr)
        #plt.plot(InterA[0], InterA[1], "mo")
        print("InterA",InterA)    
    if(InterC[1] < np.inf):
        if(draw):
            drawPointColor(InterC[0], InterC[1], "mo", axCurr)
        #plt.plot(InterC[0], InterC[1], "mo")
        print("InterC",InterC)    
    
    
    if(len(InterListA) == 1 and len(InterListC) == 1):
        print("Case 1")
        print("BEFORE RETURNING A")
        printList(Q_A)
        print("BEFORE RETURNING C")
        printList(Q_C)
        print("RETURNING p, q ",p,q)
        #return Q_A, Q_C
        return p, q

        
    if(len(InterListA) == 1 and len(InterListC) > 1):
        print("Case 2 or 3")
        #for i in range(len(InterListC)):
         #   if(not checkDuplicate(InterListC[i], q)):
          #      print(InterListC[i][1], q[1])
        if(InterC[1] < q[1]):
            print("Case 2")
            #Delete A y-lower than p
            #Delete C y-higher than q
            print("BEFORE A")
            printList(Q_A)
            print("BEFORE C")
            printList(Q_C)
            for i in range(len(Q_A)-1, pID, -1):
                Q_A.pop(i)       
            #for i in range(qID+1, -1, -1):
            for i in range(qID, -1, -1):
            #for i in range(0,qID+1):
                Q_C.pop(i)
            print("AFTER A")
            printList(Q_A)
            print("AFTER C")
            printList(Q_C)
            return findBridge(Q_A, Q_C, fig, iteration+1)
        else:
            print("Case 3")
            print("BEFORE A")
            printList(Q_A)
            print("BEFORE C")
            printList(Q_C)
            for i in range(len(Q_A)-1, pID, -1):
                Q_A.pop(i) 
            for i in range(len(Q_C)-1, qID-1, -1):
                Q_C.pop(i)
            print("AFTER A")
            printList(Q_A)
            print("AFTER C")
            printList(Q_C)
            return findBridge(Q_A, Q_C, fig, iteration+1)
            
    
    if(len(InterListA) > 1 and len(InterListC) == 1):
        print("Case 4 or 5")
        #for i in range(len(InterListA)):
        #    if(not checkDuplicate(InterListA[i], p)):
          #      print(InterListA[i][1], p[1])
        if(InterA[1] > p[1]):
            print("Case 4")
            print("BEFORE A")
            printList(Q_A)
            print("BEFORE C")
            printList(Q_C)
            for i in range(len(Q_A)-1, pID-1, -1):
                Q_A.pop(i)       
            #for i in range(qID+1, -1, -1):
            for i in range(qID-1, -1, -1):
                Q_C.pop(i)
            print("AFTER A")
            printList(Q_A)
            print("AFTER C")
            printList(Q_C)
            return findBridge(Q_A, Q_C, fig, iteration+1)
        else:
            print("Case 5")
            print("BEFORE A")
            printList(Q_A)
            print("BEFORE C")
            printList(Q_C)
            for i in range(pID, -1, -1):
                Q_A.pop(i)       
            for i in range(qID-1, -1, -1):
                Q_C.pop(i)
            print("AFTER A")
            printList(Q_A)
            print("AFTER C")
            printList(Q_C)
            return findBridge(Q_A, Q_C, fig, iteration+1)
                    
    if(len(InterListA) > 1 and len(InterListC) > 1):
        print("Case 6 or 7 or 8")
        if(InterA[1] > p[1] and InterC[1] < q[1]):
            print("Case 6")
            print("BEFORE A")
            printList(Q_A)
            print("BEFORE C")
            printList(Q_C)
            for i in range(len(Q_A)-1, pID-1, -1):
                Q_A.pop(i)         
            for i in range(qID, -1, -1):
                Q_C.pop(i)
            print("AFTER A")
            printList(Q_A)
            print("AFTER C")
            printList(Q_C)
            return findBridge(Q_A, Q_C, fig, iteration+1)
        if(InterA[1] < p[1] and InterC[1] < q[1]):
            print("Case 7")
            print("BEFORE A")
            printList(Q_A)
            print("BEFORE C")
            printList(Q_C)
            #for i in range(len(Q_A)-1, pID-1, -1):
             #   Q_A.pop(i)       
            for i in range(qID, -1, -1):
                Q_C.pop(i)
            print("AFTER A")
            printList(Q_A)
            print("AFTER C")
            printList(Q_C)
            return findBridge(Q_A, Q_C, fig, iteration+1)
        if(InterA[1] > p[1] and InterC[1] > q[1]):
            print("Case 8")
            print("BEFORE A")
            printList(Q_A)
            print("BEFORE C")
            printList(Q_C)
            for i in range(len(Q_A)-1, pID-1, -1):
                Q_A.pop(i)       
            #for i in range(qID-1, -1, -1):
            #    Q_C.pop(i)
            print("AFTER A")
            printList(Q_A)
            print("AFTER C")
            printList(Q_C)
            return findBridge(Q_A, Q_C, fig, iteration+1)
            
            ############################
            ######### CASE 9 ###########
            ############################

# %%
def TestQStructs(leafs):
    Q1 = []
    Q2 = []
    Q1.append(leafs[0])
    Q1.append(leafs[1])
    Q1.append(leafs[2])
    Q1.append(leafs[3])
    Q1.append(leafs[4])
    
    Q2.append(leafs[5])
    Q2.append(leafs[6])
    Q2.append(leafs[7])
    Q2.append(leafs[8])
    Q2.append(leafs[9])
    
    return Q1, Q2

# %%
def dynamicConvexHull(points, fig):
    n = len(points)
            
    #every point is a leaf
    #root is full lc/rc-hull
    
    yList = []
    for i in range(n):
        yList.append(points[i].y)
    
    sortedByY = [x for _, x in sorted(zip(yList, points), reverse=False)]  #sort points according to their y-value
    
    #printList(sortedByY)
    
    listNodes = []
    
    for i in range(len(sortedByY)):
        temp = sortedByY[i]
        node = InnerNode(Q=[temp], lson=[temp], rson=[temp])
        listNodes.append(node)
    
    #Q1,Q2 = TestQStructs(sortedByY)
    
    #node1 = InnerNode(Q=Q1, lson=Q1, rson=Q1)
    #node2 = InnerNode(Q=Q2, lson=Q1, rson=Q2)
    #listNodes.append(node1)
    #listNodes.append(node2)
    
    #for i in range(4,n,5):
        #leaf1 = sortedByY[i]
        #leaf2 = sortedByY[i-1]
        #leaf3 = sortedByY[i-2]
        #leaf4 = sortedByY[i-3]
        #leaf5 = sortedByY[i-4]
        #Q = [leaf1, leaf2, leaf3, leaf4, leaf5]
        #Q = TestQStructs(sortedby)
        #node = InnerNode(idd=i, lson=[leaf3,leaf4], rson=[leaf1,leaf2], maxY=leaf2.y, Q=Q)
        #listNodes.append(node)
    
    for i in range(len(listNodes)):
        listNodes[i].printData()
        print("------")
        
    nextNodes = []
    for i in range(0, len(listNodes)-1, 2):
        p,q = findBridge(listNodes[i+1].Q, listNodes[i].Q, fig, 0, draw=False)
        print("RECEIVED: ",p, q)
        print("EHELP ", type(p), type(q))
        print(type(listNodes[i+1].Q), type(listNodes[i].Q))
        print(type(listNodes[i+1].Q[0]), type(listNodes[i].Q[0]))
        Q_F = []
        counter = 0
        if(len(listNodes[i+1].Q) > 1):
            while(not listNodes[i+1].Q[counter].x == p[0] and not listNodes[i+1].Q[counter].y == p[1]):
                Q_F.append(listNodes[i+1].Q[counter])
                counter += 1
            #Q_F.append(listNodes[i+1].Q[counter+1])
        else:
            Q_F.append(listNodes[i+1].Q[0])
        
        counter = 0
        if(len(listNodes[i].Q) > 1):
            while(not listNodes[i].Q[counter].x == q[0] and not listNodes[i].Q[counter].y == q[1]):
                Q_F.append(listNodes[i].Q[counter])
                counter += 1
            #Q_F.append(listNodes[i+1].Q[counter+1])
        else:
            Q_F.append(listNodes[i].Q[0])
        
        
        #for i in range(len(Q_F)):
         #   print(Q_F)
        
        #for j in range(len(Q_A)):
        #Q_F.append(Point(Q_A[0].x, Q_A[0].y))
        #for j in range(len(Q_C)):
        #Q_F.append(Point(Q_C[0].x, Q_C[0].y))
        #Q_F.extend(Q_A)
        #Q_F.extend(Q_C)
        inNode = InnerNode(idd=1, lson=listNodes[i].Q, rson=listNodes[i+1].Q, maxY=listNodes[i].Q, Q=Q_F)
        print("===========")
        inNode.printData()
        print("===========")
        nextNodes.append(inNode)
        
### NEXT STEP SUPER STUPID ###

    print("........................................................")
    print(".....................NEXT STEP..........................")
    print("........................................................")

    nextnextNodes = []
    for i in range(0, len(nextNodes)-1, 2):###########i+1 ist A i ist C
        p, q = findBridge(nextNodes[i+1].Q, nextNodes[i].Q, fig, 0, draw=True)
        print("RECEIVED: ",p, q)
        print("EHELP ", type(p), type(q))
        print(nextNodes[i+1].Q[0].y, nextNodes[i].Q[0].y)
        print(type(nextNodes[i+1].Q), type(nextNodes[i].Q))
        print(type(nextNodes[i+1].Q[0]), type(nextNodes[i].Q[0]))
        Q_F = []
        counter = 0
        if(len(nextNodes[i].Q) > 1):
            while(not nextNodes[i].Q[counter].x == p[0] and not nextNodes[i].Q[counter].y == p[1]):
                Q_F.append(nextNodes[i].Q[counter])
                counter += 1
            if(nextNodes[i].Q[counter].x == p[0] and nextNodes[i].Q[counter].y == p[1]):
                Q_F.append(listNodes[i].Q[counter])
        else:
            Q_F.append(nextNodes[i].Q[0])
        
        counter = len(nextNodes[i+1].Q)-1
        if(len(nextNodes[i+1].Q) > 1):
            while(not nextNodes[i+1].Q[counter].x == q[0] and not nextNodes[i+1].Q[counter].y == q[1]):
                Q_F.append(nextNodes[i+1].Q[counter])
                counter -= 1
            if(nextNodes[i+1].Q[counter].x == p[0] and nextNodes[i+1].Q[counter].y == p[1]):
                Q_F.append(listNodes[i+1].Q[counter])
        else:
            Q_F.append(nextNodes[i].Q[0])
        inNode = InnerNode(idd=1, lson=nextNodes[i].Q, rson=nextNodes[i+1].Q, maxY=nextNodes[i].Q, Q=Q_F)
        print("===========")
        inNode.printData()
        print("===========")
        nextnextNodes.append(inNode)

# %%
max = 10

fig = plt.figure(figsize=(20,5))

#points = create_points_circle(max,10)
#points = create_points_arc(max,6)
points1 = create_points_arc(max,5, 0)
points2 = create_points_arc(max,5, max*2)
#points1.extend(points2)
points = points1
for i in range(len(points2)):
    points.append(points2[i])
#points = create_points_circle(max,10)
resultList = dynamicConvexHull(points,fig)
#plotPoints(points, Y0, showAngles=True, hull=resultList)
# Out:
# id: None, f: NONE, lson: [1], rson: [1], maxY: None, Q: [1], B: NONE
# ------
# id: None, f: NONE, lson: [5], rson: [5], maxY: None, Q: [5], B: NONE
# ------
# id: None, f: NONE, lson: [11], rson: [11], maxY: None, Q: [11], B: NONE
# ------
# id: None, f: NONE, lson: [16], rson: [16], maxY: None, Q: [16], B: NONE
# ------
# id: None, f: NONE, lson: [20], rson: [20], maxY: None, Q: [20], B: NONE
# ------
# id: None, f: NONE, lson: [21], rson: [21], maxY: None, Q: [21], B: NONE
# ------
# id: None, f: NONE, lson: [25], rson: [25], maxY: None, Q: [25], B: NONE
# ------
# id: None, f: NONE, lson: [30], rson: [30], maxY: None, Q: [30], B: NONE
# ------
# id: None, f: NONE, lson: [36], rson: [36], maxY: None, Q: [36], B: NONE
# ------
# id: None, f: NONE, lson: [40], rson: [40], maxY: None, Q: [40], B: NONE
# ------
# ============= ITERATION: 0 =============
# Q_A LENGTHT:  1
# Q_C LENGTHT:  1
# ::: ALL INFOS :::
# Q_A
# 2 5
# Q_C
# 7 1
# p:  [2, 5] q:  [7, 1]
# INTER LIST A: 1: [(2.0, 5.0)]
# INTER LIST C: 1: [(7.0, 1.0)]
# p on A found!
# q on C found!
# Case 1
# BEFORE RETURNING A
# 2 5
# BEFORE RETURNING C
# 7 1
# RETURNING p, q  [2, 5] [7, 1]
# RECEIVED:  [2, 5] [7, 1]
# EHELP  <class 'list'> <class 'list'>
# <class 'list'> <class 'list'>
# <class '__main__.Point'> <class '__main__.Point'>
# ===========
# id: 1, f: NONE, lson: [1], rson: [5], maxY: [<__main__.Point object at 0x0000011447D375B0>], Q: [5,1], B: NONE
# ===========
# ============= ITERATION: 0 =============
# Q_A LENGTHT:  1
# Q_C LENGTHT:  1
# ::: ALL INFOS :::
# Q_A
# 2 16
# Q_C
# 0 11
# p:  [2, 16] q:  [0, 11]
# INTER LIST A: 1: [(2.0, 16.0)]
# INTER LIST C: 1: [(0.0, 11.0)]
# p on A found!
# q on C found!
# Case 1
# BEFORE RETURNING A
# 2 16
# BEFORE RETURNING C
# 0 11
# RETURNING p, q  [2, 16] [0, 11]
# RECEIVED:  [2, 16] [0, 11]
# EHELP  <class 'list'> <class 'list'>
# <class 'list'> <class 'list'>
# <class '__main__.Point'> <class '__main__.Point'>
# ===========
# id: 1, f: NONE, lson: [11], rson: [16], maxY: [<__main__.Point object at 0x0000011447D37850>], Q: [16,11], B: NONE
# ===========
# ============= ITERATION: 0 =============
# Q_A LENGTHT:  1
# Q_C LENGTHT:  1
# ::: ALL INFOS :::
# Q_A
# 7 21
# Q_C
# 7 20
# p:  [7, 21] q:  [7, 20]
# INTER LIST A: 1: [(7.0, 21.0)]
# INTER LIST C: 1: [(7.0, 20.0)]
# p on A found!
# q on C found!
# Case 1
# BEFORE RETURNING A
# 7 21
# BEFORE RETURNING C
# 7 20
# RETURNING p, q  [7, 21] [7, 20]
# RECEIVED:  [7, 21] [7, 20]
# EHELP  <class 'list'> <class 'list'>
# <class 'list'> <class 'list'>
# <class '__main__.Point'> <class '__main__.Point'>
# ===========
# id: 1, f: NONE, lson: [20], rson: [21], maxY: [<__main__.Point object at 0x0000011447D37970>], Q: [21,20], B: NONE
# ===========
# ============= ITERATION: 0 =============
# Q_A LENGTHT:  1
# Q_C LENGTHT:  1
# ::: ALL INFOS :::
# Q_A
# 0 30
# Q_C
# 2 25
# p:  [0, 30] q:  [2, 25]
# INTER LIST A: 1: [(0.0, 30.0)]
# INTER LIST C: 1: [(2.0, 25.0)]
# p on A found!
# q on C found!
# Case 1
# BEFORE RETURNING A
# 0 30
# BEFORE RETURNING C
# 2 25
# RETURNING p, q  [0, 30] [2, 25]
# RECEIVED:  [0, 30] [2, 25]
# EHELP  <class 'list'> <class 'list'>
# <class 'list'> <class 'list'>
# <class '__main__.Point'> <class '__main__.Point'>
# ===========
# id: 1, f: NONE, lson: [25], rson: [30], maxY: [<__main__.Point object at 0x0000011447D376A0>], Q: [30,25], B: NONE
# ===========
# ============= ITERATION: 0 =============
# Q_A LENGTHT:  1
# Q_C LENGTHT:  1
# ::: ALL INFOS :::
# Q_A
# 7 40
# Q_C
# 2 36
# p:  [7, 40] q:  [2, 36]
# INTER LIST A: 1: [(7.0, 40.0)]
# INTER LIST C: 1: [(2.0, 36.0)]
# p on A found!
# q on C found!
# Case 1
# BEFORE RETURNING A
# 7 40
# BEFORE RETURNING C
# 2 36
# RETURNING p, q  [7, 40] [2, 36]
# RECEIVED:  [7, 40] [2, 36]
# EHELP  <class 'list'> <class 'list'>
# <class 'list'> <class 'list'>
# <class '__main__.Point'> <class '__main__.Point'>
# ===========
# id: 1, f: NONE, lson: [36], rson: [40], maxY: [<__main__.Point object at 0x0000011447D37DF0>], Q: [40,36], B: NONE
# ===========
# ........................................................
# .....................NEXT STEP..........................
# ........................................................
# ============= ITERATION: 0 =============
# Q_A LENGTHT:  2
# Q_C LENGTHT:  2
# ::: ALL INFOS :::
# Q_A
# 2 16
# 0 11
# Q_C
# 2 5
# 7 1
# p:  [0, 11] q:  [7, 1]
# INTER LIST A: 1: [(-0.0, 11.0)]
# INTER LIST C: 3: [(7.0, 1.0), (4.2, 5.0), (7.0, 1.0)]
# p on A found!
# InterC (4.2, 5.0)
# Case 2 or 3
# Case 3
# BEFORE A
# 2 16
# 0 11
# BEFORE C
# 2 5
# 7 1
# AFTER A
# 2 16
# 0 11
# AFTER C
# 2 5
# ============= ITERATION: 1 =============
# Q_A LENGTHT:  2
# Q_C LENGTHT:  1
# ::: ALL INFOS :::
# Q_A
# 2 16
# 0 11
# Q_C
# 2 5
# p:  [0, 11] q:  [2, 5]
# INTER LIST A: 1: [(-0.0, 11.0)]
# INTER LIST C: 1: [(2.0, 5.0)]
# p on A found!
# q on C found!
# Case 1
# BEFORE RETURNING A
# 2 16
# 0 11
# BEFORE RETURNING C
# 2 5
# RETURNING p, q  [0, 11] [2, 5]
# RECEIVED:  [0, 11] [2, 5]
# EHELP  <class 'list'> <class 'list'>
# 16 5
# <class 'list'> <class 'list'>
# <class '__main__.Point'> <class '__main__.Point'>
# ===========
# id: 1, f: NONE, lson: [5], rson: [16,11], maxY: [<__main__.Point object at 0x0000011447D37D90>], Q: [5,11], B: NONE
# ===========
# ============= ITERATION: 0 =============
# Q_A LENGTHT:  2
# Q_C LENGTHT:  2
# ::: ALL INFOS :::
# Q_A
# 0 30
# 2 25
# Q_C
# 7 21
# 7 20
# p:  [2, 25] q:  [7, 20]
# INTER LIST A: 1: [(2.0, 25.0)]
# INTER LIST C: 1: [(7.0, 20.0)]
# p on A found!
# q on C found!
# Case 1
# BEFORE RETURNING A
# 0 30
# 2 25
# BEFORE RETURNING C
# 7 21
# 7 20
# RETURNING p, q  [2, 25] [7, 20]
# RECEIVED:  [2, 25] [7, 20]
# EHELP  <class 'list'> <class 'list'>
# 30 21
# <class 'list'> <class 'list'>
# <class '__main__.Point'> <class '__main__.Point'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-307-64297d27176e> in <module>
#      12     points.append(points2[i])
#      13 #points = create_points_circle(max,10)
# ---> 14 resultList = dynamicConvexHull(points,fig)
#      15 #plotPoints(points, Y0, showAngles=True, hull=resultList)
#
# <ipython-input-306-48b7b06997cc> in dynamicConvexHull(points, fig)
#     101         counter = 0
#     102         if(len(nextNodes[i].Q) > 1):
# --> 103             while(not nextNodes[i].Q[counter].x == p[0] and not nextNodes[i].Q[counter].y == p[1]):
#     104                 Q_F.append(nextNodes[i].Q[counter])
#     105                 counter += 1
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt

# start with one
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2,3])


# now later you get a new subplot; change the geometry of the existing
n = len(fig.axes)
for i in range(n):
    fig.axes[i].change_geometry(n+1, 1, i+1)

# add the new
ax = fig.add_subplot(n+1, 1, n+1)
ax.plot([4,5,6])

ax = fig.add_subplot(n+2, 1, n+2)
ax.plot([7,8,9])

n = len(fig.axes)
for i in range(n):
    fig.axes[i].change_geometry(n+1, 1, i+1)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

f = plt.figure(figsize=(10,5))
axList = []
row = 1
coords = 1
for i in range(1,6):
    strg = "3"
    #coords = "1"
    if(i % 3 == 0):
        coords += 1
        row += 1
    #coordStr = "{}".format(coords)
    rowStr = "{}".format(row)
    colStr = "{}".format(i%3)
    #coords += colStr
    #coords += rowStr
    #strg += coordStr
    strg += colStr
    strg += rowStr
    
    print(strg)
    axList.append(f.add_subplot(int(strg)))
#ax = f.add_subplot(121)
#ax2 = f.add_subplot(122)
x = np.linspace(0,4,1000)
for i in range(len(axList)):
    axList[i].plot(x, np.sin(x))
    axList[i].grid()
#ax
#ax2.plot(x, np.cos(x), 'r:')
# Out:
# 311
# 321
# 302
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-2f1757d0c1f7> in <module>
#      22
#      23     print(strg)
# ---> 24     axList.append(f.add_subplot(int(strg)))
#      25 #ax = f.add_subplot(121)
#      26 #ax2 = f.add_subplot(122)
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     674                 cbook.warn_deprecated("3.3", message=message)
#     675                 rows, cols = map(int, [rows, cols])
# --> 676             gs = GridSpec(rows, cols, figure=figure)
#     677             if isinstance(num, tuple) and len(num) == 2:
#     678                 if not all(isinstance(n, Integral) for n in num):
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in __init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     418         self.figure = figure
#     419
# --> 420         GridSpecBase.__init__(self, nrows, ncols,
#     421                               width_ratios=width_ratios,
#     422                               height_ratios=height_ratios)
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in __init__(self, nrows, ncols, height_ratios, width_ratios)
#      49                 f"Number of rows must be a positive integer, not {nrows}")
#      50         if not isinstance(ncols, Integral) or ncols <= 0:
# ---> 51             raise ValueError(
#      52                 f"Number of columns must be a positive integer, not {ncols}")
#      53         self._nrows, self._ncols = nrows, ncols
#
# ValueError: Number of columns must be a positive integer, not 0

# %%
import matplotlib.pyplot as plt
from pylab import *
import numpy as np

x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

subplots_adjust(hspace=0.000)
number_of_subplots=10

for i,v in enumerate(range(number_of_subplots)):
    v = v+1
    ax1 = subplot(1,number_of_subplots,v, xscale=10, yscale=10)
    ax1.plot(x,y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-ab515fed11fb> in <module>
#      11 for i,v in enumerate(range(number_of_subplots)):
#      12     v = v+1
# ---> 13     ax1 = subplot(1,number_of_subplots,v, xscale=10, yscale=10)
#      14     ax1.plot(x,y)
#      15
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     519
#     520         if xscale:
# --> 521             self.set_xscale(xscale)
#     522         if yscale:
#     523             self.set_yscale(yscale)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_xscale(self, value, **kwargs)
#    3380         g = self.get_shared_x_axes()
#    3381         for ax in g.get_siblings(self):
# -> 3382             ax.xaxis._set_scale(value, **kwargs)
#    3383             ax._update_transScale()
#    3384             ax.stale = True
#
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in _set_scale(self, value, **kwargs)
#     753
#     754     def _set_scale(self, value, **kwargs):
# --> 755         self._scale = mscale.scale_factory(value, self, **kwargs)
#     756         self._scale.set_default_locators_and_formatters(self)
#     757
#
# ~\anaconda3\lib\site-packages\matplotlib\scale.py in scale_factory(scale, axis, **kwargs)
#     646     axis : `matplotlib.axis.Axis`
#     647     """
# --> 648     scale = scale.lower()
#     649     cbook._check_in_list(_scale_mapping, scale=scale)
#     650     return _scale_mapping[scale](axis, **kwargs)
#
# AttributeError: 'int' object has no attribute 'lower'
